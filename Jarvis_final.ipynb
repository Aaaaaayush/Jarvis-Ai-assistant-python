# %%
import os
import time
import psutil
import pyaudio
import pyjokes
import smtplib
import pyttsx3
import weakref
import datetime
import pywhatkit
import webbrowser
import subprocess
import speech_recognition as sr  
from googlesearch import search
from playsound import playsound
try:
    playsound(mp3path)
except:
    pass

r = sr.Recognizer()
engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
# print(voices[1].id)
engine.setProperty('voice', voices[0].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    hour = int(datetime.datetime.now().hour)
    if hour >= 0 and hour < 12:
        speak("Good Morning Sir")
    elif hour >= 12 and hour < 18:
        speak("Good Afternoon Sir")   
    else:
        speak("Good Evening Sir")  

    speak("how may i assist you")       

def takeCommand():

    r = sr.Recognizer() 
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 2
        audio = r.listen(source)
    try:
        print("Recognizing...") 
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}\n")

    except Exception as e:  
        print("Say that again please...")  
        return "None"
    return query

if __name__ == "__main__":
    wishMe()
    while True:
        query = takeCommand().lower()

        if 'search' in query:
            speak('Searching google...')
            query = query.replace("google", "")
            for j in search(query, tld="co.in", num=1, stop=1, pause=2):
                webbrowser.open(j)
                print(j)
                speak("opened in web browser")

        elif 'open youtube' in query:
            speak("sir may i interest you in checking the trending section")
            webbrowser.open("youtube.com")

        elif 'open google' in query:
            speak("will do sir")
            webbrowser.open("google.com")

        elif 'open stack overflow' in query:
            speak("I am On it")
            webbrowser.open("stackoverflow.com")

        elif 'wakanda forever' in query:
            speak("wakanda forever")
            webbrowser.open("https://www.marvel.com/")

        elif 'who created you' in query:
            speak("i am a creation of master aayush")

        elif 'jarvis you up' in query:
            speak("for you sir always")
            
        elif 'goodbye' in query:
            speak("As always sir. a great pleasure watching you work")

        elif 'your task' in query:
            speak("running and taking care of all the internal systems on and off the home network")
            
        elif 'full form' in query:
            speak("jarvis is an acronym for just a rather very intelligent system")

        elif 'introduce yourself' in query:
            playsound(r'C:\Users\Ayush\Desktop\ Jarvis\jarvis intro.mp3')

        elif 'play some music' in query:
            speak("here is your favourite song") 
            playsound(r'C:\Users\Ayush\Desktop\ Jarvis\AC DC Back in black (128 kbps).mp3')

        elif 'what is the time' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")    
            speak(f"Sir, the time is {strTime}")

        elif 'open shield database' in query:
            speak("starting private network. accessing confidential shield files")
            subprocess.Popen(r'explorer /select,"C:\Users\Ayush\Desktop\ Jarvis"')
                
        elif 'start camera' in query:
            speak("say cheese")
            os.system("start microsoft.windows.camera:")
            
        elif 'tell a joke' or 'make me laugh' or 'tell another joke' in query:
            speak(pyjokes.get_joke())

        elif 'battery status' in query:
            battery = psutil.sensors_battery()
            percent = battery.percent
            if percent >= 90:
                speak("i am sensing that my battery is fully charged")
            elif percent >= 80:
                speak("i am sensing that my battery is above eighty percent")
            elif percent >= 70:
                speak("i am sensing that my battery is above seventy percent")
            elif percent >= 60:
                speak("i am sensing that my battery is above sixty percent")
            elif percent >= 50:
                speak("i am sensing that my battery is above fifty percent")
            elif percent >= 40:
                speak("i am sensing that my battery is above forty percent")
            elif percent >= 20:
                speak("i am sensing that my battery is above twenty percent")
            else:
                speak("We are now running on emergency backup power")
# Out:
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.80334973,
#                            'transcript': 'battery status'},
#                        {'transcript': 'sad status'},
#                        {'transcript': 'Ragni status'},
#                        {'transcript': 'Rider status'},
#                        {'transcript': 'status'}],
#     'final': True}
# User said: battery status
#
# Listening...
# Recognizing...
# result2:
# []
# Say that again please...
# Listening...
# Recognizing...
# result2:
# {   'alternative': [   {   'confidence': 0.61704659,
#                            'transcript': 'battery status'},
#                        {'transcript': 'train status'},
#                        {'transcript': 'status'},
#                        {'transcript': 'birthday status'},
#                        {'transcript': 'new status'}],
#     'final': True}
# User said: battery status
#
# Listening...
# Recognizing...
# result2:
# ...

# %%
# search "anything you want to know"
# open youtube
# open google
# open stackoverflow
# wakanda forever "opens marvel website"
# who created you 
# jarvis you up
# goodbye
# your task
# full form
# introduce yourself
# play some music
# what is the time
# open shield database
# start camera
# battery status
# tell a joke / make me laugh / tell another joke
